# %%
import requests
import json
from pprint import pprint
import time
#from api_keys import alpha_vantage_key
api_key = '1BRDPG4A7V2DTHYH'

# %%
# url = 'https://www.alphavantage.co/'
# function = 'sector'
#query_url = f'{url}query?function={function}&apikey={api_key}'
companies ={'FB','GOOGL','AAPL','MSFT','TWTR','UNH','HUM','PFE','JNJ','HCA','DAL','BA','CCL','UAL','STWD'
         ,'AMZN','WMT','JCP','TGT','M','JPM','C','BRKB','WFC','BAC'}
url='https://www.alphavantage.co/query?'
function ='TIME_SERIES_DAILY_ADJUSTED'
companies_df = pd.DataFrame()
#symbols = '&symbol='+companies
#query_url = f'{url}function={function}&symbol={symbols}&apikey={api_key}'

# %%
for company in companies:
    print(company)
    query_url = f'{url}function={function}&symbol={company}&apikey={api_key}'
    request_1 = requests.get(query_url).json()
    time.sleep(14)
    pprint(request_1)
# Out:
# GOOGL
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend '
#                                  'Events',
#                '2. Symbol': 'GOOGL',
#                '3. Last Refreshed': '2020-04-15',
#                '4. Output Size': 'Compact',
#                '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2019-11-20': {'1. open': '1311.3600',
#                                         '2. high': '1313.2100',
#                                         '3. low': '1289.2100',
#                                         '4. close': '1301.8600',
#                                         '5. adjusted close': '1301.8600',
#                                         '6. volume': '1445870',
#                                         '7. dividend amount': '0.0000',
#                                         '8. split coefficient': '1.0000'},
#                          '2019-11-21': {'1. open': '1299.2500',
# ...

# %%
# token = 'Tsk_0be3bb139a3c477680774e81f25fbffb'
# url_1= f'https://sandbox.iexapis.com/stable/stock/market/sector-performance?token={token}'
# request_2 = requests.get(url_1).json()
# pprint(request_2)
